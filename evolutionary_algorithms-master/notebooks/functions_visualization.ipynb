# %%
from evolutionary.optim_functions import *

# %matplotlib inline

f_list = [Ackley(),
         Griewank(),
         Beale(),
         Booth(),
         Rothyp(),
         Forrester(),
         Matyas(),
         Zakharov(),
         Easom()]

# Plot all the functions to test that they have been implemented correctly
for f in f_list:
    f.plot()
